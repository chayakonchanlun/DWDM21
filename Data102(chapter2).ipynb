# %% [markdown]
# <a href="https://colab.research.google.com/github/chayakonchanlun/DWDM21/blob/main/Data102(chapter2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #ทำงานกับข้อมูลลักษณะตาราง

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
ls

# %%
import os #จัดการไฟล์เเละ path

# %%
path = '/content/drive/My Drive/DWDM2021_DATA'

# %%
data = pd.read_csv(os.path.join(path,'thailand_covid-19_testing_data.csv'))
data

# %%
data.iloc[:,:3] #ตัดdataตามที่เราต้องการ[แถว,หลัก]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1aa5e7399ddc> in <module>()
# ----> 1 data.iloc[:,:3] #ตัดdataตามที่เราต้องการ[แถว,หลัก]
#
# NameError: name 'data' is not defined

# %%
dataN = data.iloc[:,:3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4314d655dd7b> in <module>()
# ----> 1 dataN = data.iloc[:,:3]
#
# NameError: name 'data' is not defined

# %%
dataN
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d1c7412abf05> in <module>()
# ----> 1 dataN
#
# NameError: name 'dataN' is not defined

# %% [markdown]
# ## .head() .tail()**ทำข้อความเป็นตัวหนา**

# %%
dataN.head() #ดูหัวตาราง
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ba8a606ac662> in <module>()
# ----> 1 dataN.head() #ดูหัวตาราง
#
# NameError: name 'dataN' is not defined

# %%
dataN.tail() #ดูท้ายตาราง
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-05b7343372f5> in <module>()
# ----> 1 dataN.tail() #ดูท้ายตาราง
#
# NameError: name 'dataN' is not defined

# %%
dataN.head(10) #บอกค่าตามที่เราอยากโชว์
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-dbe06950ce45> in <module>()
# ----> 1 dataN.head(10) #บอกค่าตามที่เราอยากโชว์
#
# NameError: name 'dataN' is not defined

# %%
dataN.head(n=13)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-0302a5cd52c2> in <module>()
# ----> 1 dataN.head(n=13)
#
# NameError: name 'dataN' is not defined

# %%
dataN.tail(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-27eafc9ac92f> in <module>()
# ----> 1 dataN.tail(20)
#
# NameError: name 'dataN' is not defined

# %%
dataN.describe() #ดูค่าทางสถิติ
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-6d66287e3c9a> in <module>()
# ----> 1 dataN.describe() #ดูค่าทางสถิติ
#
# NameError: name 'dataN' is not defined

# %% [markdown]
# ## **Boxplot**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from matplotlib import pyplot as plt # ใช้วาดกราฟ

# %%
dataN['positive'][1:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-367bc87ac99e> in <module>()
# ----> 1 dataN['positive'][1:]
#
# NameError: name 'dataN' is not defined

# %%
plt.boxplot(dataN['positive'][1:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d375f0096950> in <module>()
# ----> 1 plt.boxplot(dataN['positive'][1:])
#
# NameError: name 'dataN' is not defined

# %%
plt.boxplot(dataN['Total Testing'][1:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-482133b13917> in <module>()
# ----> 1 plt.boxplot(dataN['Total Testing'][1:])
#
# NameError: name 'dataN' is not defined

# %%
ret = plt.boxplot(dataN['positive'][-54:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-9ccb2333e440> in <module>()
# ----> 1 ret = plt.boxplot(dataN['positive'][-54:])
#
# NameError: name 'dataN' is not defined

# %%
ret = plt.boxplot(dataN['Total Testing'][-54:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-879824fbab7f> in <module>()
# ----> 1 ret = plt.boxplot(dataN['Total Testing'][-54:])
#
# NameError: name 'dataN' is not defined

# %% [markdown]
# ## Time Series **Plot**

# %%
len(dataN['positive'][1:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-5a0882fce485> in <module>()
# ----> 1 len(dataN['positive'][1:])
#
# NameError: name 'dataN' is not defined

# %%
plt.plot(range(len(dataN['positive'][1:])),dataN['positive'][1:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-5b586d1b51fe> in <module>()
# ----> 1 plt.plot(range(len(dataN['positive'][1:])),dataN['positive'][1:])
#
# NameError: name 'dataN' is not defined

# %%
plt.plot(range(len(dataN['positive'][1:-7])),dataN['positive'][1:-7])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-1fcfcc067936> in <module>()
# ----> 1 plt.plot(range(len(dataN['positive'][1:-7])),dataN['positive'][1:-7])
#
# NameError: name 'dataN' is not defined

# %%
plt.plot(range(len(dataN['Total Testing'][1:-7])),dataN['Total Testing'][1:-7])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-1fbec1a4d9c2> in <module>()
# ----> 1 plt.plot(range(len(dataN['Total Testing'][1:-7])),dataN['Total Testing'][1:-7])
#
# NameError: name 'dataN' is not defined

# %%
plt.plot(range(len(dataN['positive'][1:-7])),dataN['positive'][1:-7],'r--')
plt.plot(range(len(dataN['Total Testing'][1:-7])),dataN['Total Testing'][1:-7],'b--')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-464a3f4f59ea> in <module>()
# ----> 1 plt.plot(range(len(dataN['positive'][1:-7])),dataN['positive'][1:-7],'r--')
#       2 plt.plot(range(len(dataN['Total Testing'][1:-7])),dataN['Total Testing'][1:-7],'b--')
#
# NameError: name 'dataN' is not defined

# %%
plt.plot(range(len(dataN['positive'][450:])),dataN['positive'][450:],'r--')
plt.plot(range(len(dataN['Total Testing'][450:])),dataN['Total Testing'][450:],'b--')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-df24890f6e38> in <module>()
# ----> 1 plt.plot(range(len(dataN['positive'][450:])),dataN['positive'][450:],'r--')
#       2 plt.plot(range(len(dataN['Total Testing'][450:])),dataN['Total Testing'][450:],'b--')
#
# NameError: name 'dataN' is not defined
